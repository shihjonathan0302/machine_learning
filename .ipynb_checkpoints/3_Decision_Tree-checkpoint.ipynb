# %% [markdown]
# # 3. Decision Tree

# %%
# Load and Preview Data
import pandas as pd
df = pd.read_csv("ml_customer_data.csv")
df.head()
# Out:
#    age  salary  purchased
# 0   56   19000          0
# 1   46   85588          1
# 2   32   53304          1
# 3   60   84449          1
# 4   25   97986          0

# %%
# Split Features and Targets
from sklearn.model_selection import train_test_split
X = df[['age', 'salary']]
y = df['purchased']

# 70% training, 30% testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
# Train a Decision Tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state = 42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Make Predictions and Evaluate Accuracy
# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate accuracy
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334

# %%
# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report

# Confusion matrix shows counts of TP, TN, FP, FN
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Precision, Recall, F1-score, Support
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[76 16]
#  [ 9 49]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        92
#            1       0.75      0.84      0.80        58
#
#     accuracy                           0.83       150
#    macro avg       0.82      0.84      0.83       150
# weighted avg       0.84      0.83      0.83       150

# %%
# Visualize the Tree
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(12, 6))
plot_tree(model, feature_names=['age', 'salary'], class_names=['No', 'Yes'], filled=True)
plt.title("Decision Tree for Purchase Prediction")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Feature Importance
# Which features matter most in the decision process?
print("Feature Importances:")
for name, importance in zip(X.columns, model.feature_importances_):
    print(f"{name}: {importance:.4f}")
# Out:
# Feature Importances:
# age: 0.3497
# salary: 0.6503

# %% [markdown]
# ## 🌳 Model Summary
#
# This section summarizes the performance and interpretation of the Decision Tree classifier trained to predict whether a customer will purchase based on their age and salary.
#
# **Accuracy:**
# 0.8333
# The model correctly predicted customer purchase behavior 83.33% of the time.
#
# ---
#
# **Confusion Matrix:**
# [[76 16]
#  [ 9 49]]
#
# | Actual \\ Predicted | Predicted 0 (No Purchase) | Predicted 1 (Purchase) |
# |---------------------|----------------------------|-------------------------|
# | Actual 0            | 76 (True Negative)         | 16 (False Positive)     |
# | Actual 1            | 9 (False Negative)         | 49 (True Positive)      |
#
# - The model correctly identified:
#   - 76 non-purchasing customers (TN)
#   - 49 purchasing customers (TP)
# - 16 customers were wrongly predicted as buyers (FP)
# - 9 customers who did purchase were missed (FN)
#
# ---
#
# **Classification Report:**
#
# | Class | Precision | Recall | F1-score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.83      | 0.83   | 0.86     | 92      |
# | 1     | 0.75      | 0.84   | 0.80     | 58      |
# | **Overall Accuracy** | — | — | **0.83** | 150     |
# | **Macro Avg** | 0.82 | 0.84 | 0.83 | 150 |
# | **Weighted Avg** | 0.84 | 0.83 | 0.83 | 150 |
#
# - **Precision (class 1)** = 0.75 → 75% of predicted buyers actually bought.
# - **Recall (class 1)** = 0.84 → Model found 84% of all real buyers.
# - **F1-score** = 0.80 → Strong balance between precision and recall.
#
# ---
#
# **Tree Visualization:**
# The plotted tree shows the decision rules (based on salary and age) the model uses to classify each customer. Each node splits on a condition such as `salary <= 52500.5` and leads to different outcomes based on how the data is partitioned.
#
# - Darker colors indicate purer nodes (i.e., mostly one class)
# - Leaves show predicted class and class distribution at that point
# - The tree is interpretable, but can become deep or overfit if not pruned
#
# ---
#
# ### ✅ Final Conclusion
#
# The Decision Tree classifier achieved a solid 83% accuracy, with high recall for both classes. It's highly interpretable and visually shows how age and salary contribute to purchase decisions. However, Decision Trees may overfit if left unpruned or trained on noisy data. In this case, the model performed well and could be a reliable baseline for customer purchase classification.

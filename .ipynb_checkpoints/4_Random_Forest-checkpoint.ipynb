# %% [markdown]
# # 4. Random Forest

# %%
# Load and Preview Data
import pandas as pd
df = pd.read_csv("ml_customer_data.csv")
df.head()
# Out:
#    age  salary  purchased
# 0   56   19000          0
# 1   46   85588          1
# 2   32   53304          1
# 3   60   84449          1
# 4   25   97986          0

# %%
# Prepare Features and Target
from sklearn.model_selection import train_test_split
X = df[['age', 'salary']]
y = df['purchased']

# Split the dataset: 70% training, 30% testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
# Train the Random Forest Classfier
from sklearn.ensemble import RandomForestClassifier

# Create the model
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Fit it on the training data
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict and Evaluate Accuracy
from sklearn.metrics import accuracy_score

# Predict the test set
y_pred = model.predict(X_test)

# Print the accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8866666666666667

# %%
# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report

# Confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[80 12]
#  [ 5 53]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90        92
#            1       0.82      0.91      0.86        58
#
#     accuracy                           0.89       150
#    macro avg       0.88      0.89      0.88       150
# weighted avg       0.89      0.89      0.89       150

# %%
# Fearure Importance
# See which feature(s) the forest considers most important
import matplotlib.pyplot as plt

feature_names = X.columns
importances = model.feature_importances_

# Plot the feature importances
plt.bar(feature_names, importances)
plt.title("Feature Importance in Random Forest")
plt.ylabel("Importance")
plt.show()

# %% [markdown]
# ## 🌲 Model Summary
#
# This section summarizes the performance and interpretation of the Random Forest classifier trained to predict whether a customer will purchase based on their age and salary.
#
# **Accuracy:**
# 0.8867
# The model correctly predicted purchase behavior with **88.67%** accuracy, which is the highest so far among tested models.
#
# ---
#
# **Confusion Matrix:**
# [[80 12]
#  [ 5 53]]
#
# | Actual \\ Predicted | Predicted 0 (No Purchase) | Predicted 1 (Purchase) |
# |---------------------|----------------------------|-------------------------|
# | Actual 0            | 80 (True Negative)         | 12 (False Positive)     |
# | Actual 1            | 5 (False Negative)         | 53 (True Positive)      |
#
# - The model made 17 total errors out of 150 predictions.
# - It successfully identified:
#   - 80 non-buyers (TN)
#   - 53 buyers (TP)
#
# ---
#
# **Classification Report:**
#
# | Class | Precision | Recall | F1-score | Support |
# |-------|-----------|--------|----------|---------|
# | 0     | 0.94      | 0.87   | 0.90     | 92      |
# | 1     | 0.82      | 0.91   | 0.86     | 58      |
# | **Overall Accuracy** | — | — | **0.89** | 150     |
# | **Macro Avg** | 0.88 | 0.89 | 0.88 | 150 |
# | **Weighted Avg** | 0.89 | 0.89 | 0.89 | 150 |
#
# - **Precision (class 1):** 0.82 → 82% of predicted buyers were correct.
# - **Recall (class 1):** 0.91 → Model caught 91% of all actual buyers.
# - **F1-score (class 1):** 0.86 → Excellent balance between precision and recall.
#
# ---
#
# **Feature Importance:**
#
# The bar chart shows which feature had more influence on decision-making:
#
# - `salary`: ~0.66
# - `age`: ~0.34
#
# This means **salary** contributed almost twice as much as **age** to the model’s predictions. Random Forest evaluates this by calculating how much each feature reduces impurity (uncertainty) across all decision trees.
#
# ---
#
# ### ✅ Final Conclusion
#
# Random Forest delivered **strong, balanced performance**, achieving nearly 89% accuracy, with especially high recall for identifying actual purchasers. It’s more robust than a single decision tree and less prone to overfitting. The model found **salary** to be a more important predictor than age, and the results make it a strong candidate for real-world binary classification tasks.
